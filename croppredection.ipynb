# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmitha-Sa/ASMIPROJECTS/blob/main/croppredection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
import plotly.graph_objects as go

# %%
# Load Dataset
data = pd.read_csv('SmartCrop-Dataset.csv')
df = pd.DataFrame(data)

# Explore data
print("Number of Instances and Attributes:", df.shape)
print('\n')
print('Dataset columns:', df.columns)
print('\n')
print('Data types of each columns: ', df.info())
# Out:
# Number of Instances and Attributes: (2200, 8)
#
#
# Dataset columns: Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB
# Data types of each columns:  None

# %%
# Checking for Duplicates
count_dups = df.duplicated().sum()
print("Number of Duplicates: ", count_dups)
if count_dups >= 1:
    df.drop_duplicates(inplace=True)
    print('Duplicate values removed!')
else:
    print('No Duplicate values')
# Out:
# Number of Duplicates:  0
# No Duplicate values

# %%
df.max()
# Out:
# N                     140
# P                     145
# K                     205
# temperature     43.675493
# humidity        99.981876
# ph               9.935091
# rainfall       298.560117
# label          watermelon
# dtype: object

# %%
df.min()
# Out:
# N                      0
# P                      5
# K                      5
# temperature     8.825675
# humidity        14.25804
# ph              3.504752
# rainfall       20.211267
# label              apple
# dtype: object

# %%
# Find which columns are numeric
numeric_columns = df.select_dtypes(include=[np.number]).columns  # Select only numeric columns

# Plot distribution of numeric features before outlier removal
fig, axes = plt.subplots(len(numeric_columns), 1, figsize=(20, len(numeric_columns) * 5))
for i, column in enumerate(numeric_columns):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title(f'Distribution of {column} before removing outliers')
plt.tight_layout()
plt.show()

# Calculate Q1, Q3, and IQR only for numeric columns
Q1 = df[numeric_columns].quantile(0.25)
Q3 = df[numeric_columns].quantile(0.75)
IQR = Q3 - Q1

# Remove outliers using IQR method
df_out = df[~((df[numeric_columns] < (Q1 - 1.5 * IQR)) | (df[numeric_columns] > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Data without outliers:")
print(df_out)

# Plot distribution of numeric features after outlier removal
fig, axes = plt.subplots(len(numeric_columns), 1, figsize=(20, len(numeric_columns) * 5))
for i, column in enumerate(numeric_columns):
    sns.boxplot(x=df_out[column], ax=axes[i])

    axes[i].set_title(f'Distribution of {column} after removing outliers')
plt.tight_layout()
plt.show()
# Out:
# Data without outliers:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 13     93  56  36    24.014976  82.056872  6.984354  185.277339    rice
# 14     94  50  37    25.665852  80.663850  6.948020  209.586971    rice
# 17     91  35  39    23.793920  80.418180  6.970860  206.261186    rice
# 20     89  45  36    21.325042  80.474764  6.442475  185.497473    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [1768 rows x 8 columns]

# %%
# Split Data to Training and Validation set
target = 'label'
X = df_out.drop(target, axis=1)
y = df_out[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Train RandomForestClassifier to get feature importance
pipeline_rf = make_pipeline(StandardScaler(), RandomForestClassifier())
model_rf = pipeline_rf.fit(X_train, y_train)
importances = model_rf.named_steps['randomforestclassifier'].feature_importances_
indices = np.argsort(importances)[::-1]
feature_names = X.columns

fig = go.Figure()
fig.add_trace(go.Bar(x=feature_names[indices], y=importances[indices]))
fig.update_layout(title='Feature Importance',
                  xaxis_title='Feature',
                  yaxis_title='Importance')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9becfeb0-298b-4df7-9dae-94c645c3051f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9becfeb0-298b-4df7-9dae-94c645c3051f")) {                    Plotly.newPlot(                        "9becfeb0-298b-4df7-9dae-94c645c3051f",                        [{"x":["rainfall","humidity","K","P","N","temperature","ph"],"y":[0.23080643932828346,0.21862012073428555,0.15004836115833273,0.1417175266498053,0.1292883231360386,0.07470589845982398,0.05481333053343037],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay", ...

# %%
#Model training
selected_columns = [0, 1, 2, 3]
X_train_selected = X_train.iloc[:, selected_columns]
X_test_selected = X_test.iloc[:, selected_columns]

pipeline = make_pipeline(StandardScaler(), RandomForestClassifier())
model = pipeline.fit(X_train_selected, y_train)
y_pred = model.predict(X_test_selected)
print(X_train_selected)
print(X_test_selected)
print(y_train)
print(y_pred)
# Out:
#         N   P   K  temperature
# 2049  100  56  40    26.389054
# 897     4  59  19    26.250703
# 635    14  48  21    29.245990
# 201    23  72  84    19.020613
# 312    28  80  17    19.622078
# ...   ...  ..  ..          ...
# 987    11  10  45    22.630452
# 1470  115  12  52    27.514922
# 2085   87  48  38    23.815796
# 711    57  67  25    32.347440
# 836    19  72  15    28.836010
#
# [1414 rows x 4 columns]
#         N   P   K  temperature
# 2100   91  21  26    26.333780
# 822    12  66  20    27.414350
# 539     9  49  16    30.884827
# 1310   83  25  53    26.491953
# 941     5  29  44    21.024329
# ...   ...  ..  ..          ...
# 2103  108  24  31    24.128325
# 705    50  55  16    28.814607
# 1138    4  40  26    27.582589
# 1666   16  29  13    32.319444
# 682     6  47  18    29.161746
#
# [354 rows x 4 columns]
# 2049           jute
# 897          lentil
# 635        mungbean
# 201        chickpea
# 312     kidneybeans
#            ...
# 987     pomegranate
# 1470      muskmelon
# 2085           jute
# 711       blackgram
# 836          lentil
# Name: label, Length: 1414, dtype: object
# ['coffee' 'lentil' 'mothbeans' 'watermelon' 'pomegranate' 'mango'
#  'coconut' 'mango' 'coffee' 'mungbean' 'chickpea' 'kidneybeans' 'jute'
#  'chickpea' 'pigeonpeas' 'papaya' 'blackgram' 'cotton' 'chickpea' 'maize'
#  'banana' 'pigeonpeas' 'rice' 'jute' 'lentil' 'orange' 'watermelon'
#  'chickpea' 'pigeonpeas' 'maize' 'watermelon' 'coffee' 'coconut'
#  'blackgram' 'mango' 'mungbean' 'mungbean' 'lentil' 'mungbean' 'papaya'
#  'muskmelon' 'lentil' 'banana' 'pomegranate' 'cotton' 'banana'
#  'kidneybeans' 'jute' 'muskmelon' 'jute' 'pigeonpeas' 'kidneybeans'
#  'coffee' 'lentil' 'lentil' 'muskmelon' 'kidneybeans' 'kidneybeans'
#  'pigeonpeas' 'banana' 'coffee' 'coffee' 'pigeonpeas' 'maize' 'mungbean'
#  'lentil' 'jute' 'cotton' 'jute' 'kidneybeans' 'pomegranate' 'maize'
#  'lentil' 'mungbean' 'mango' 'maize' 'muskmelon' 'kidneybeans'
#  'pomegranate' 'coconut' 'mango' 'blackgram' 'kidneybeans' 'watermelon'
#  'lentil' 'coconut' 'pigeonpeas' 'coffee' 'watermelon' 'orange'
#  'watermelon' 'maize' 'cotton' 'chickpea' 'cotton' 'mungbean' 'coffee'
#  'rice' 'maize' 'pomegranate' 'pomegranate' 'pomegranate' 'pomegranate'
#  'maize' 'papaya' 'pomegranate' 'papaya' 'coconut' 'jute' 'mungbean'
#  'banana' 'watermelon' 'blackgram' 'cotton' 'lentil' 'mango' 'mango'
#  'banana' 'kidneybeans' 'pigeonpeas' 'pigeonpeas' 'coffee' 'chickpea'
#  'banana' 'jute' 'blackgram' 'coffee' 'mango' 'orange' 'orange' 'coconut'
#  'muskmelon' 'coffee' 'mungbean' 'jute' 'jute' 'watermelon' 'coconut'
#  'lentil' 'orange' 'jute' 'coffee' 'pigeonpeas' 'muskmelon' 'pigeonpeas'
#  'blackgram' 'banana' 'maize' 'muskmelon' 'lentil' 'pigeonpeas'
#  'watermelon' 'lentil' 'kidneybeans' 'pigeonpeas' 'kidneybeans' 'orange'
#  'mungbean' 'mungbean' 'watermelon' 'rice' 'maize' 'mothbeans' 'coconut'
#  'orange' 'kidneybeans' 'blackgram' 'blackgram' 'muskmelon' 'coffee'
#  'kidneybeans' 'chickpea' 'mungbean' 'cotton' 'kidneybeans' 'coconut'
#  'blackgram' 'mango' 'mungbean' 'jute' 'lentil' 'papaya' 'mango'
#  'muskmelon' 'mungbean' 'rice' 'jute' 'watermelon' 'maize' 'cotton'
#  'cotton' 'muskmelon' 'jute' 'mungbean' 'watermelon' 'jute' 'mothbeans'
#  'cotton' 'jute' 'maize' 'papaya' 'coconut' 'cotton' 'maize' 'kidneybeans'
#  'watermelon' 'papaya' 'pigeonpeas' 'coffee' 'muskmelon' 'blackgram'
#  'maize' 'maize' 'orange' 'maize' 'banana' 'orange' 'maize' 'mango'
#  'papaya' 'mungbean' 'watermelon' 'mungbean' 'banana' 'banana' 'rice'
#  'blackgram' 'watermelon' 'mungbean' 'maize' 'watermelon' 'mungbean'
#  'jute' 'orange' 'muskmelon' 'lentil' 'jute' 'mango' 'chickpea' 'banana'
#  'chickpea' 'mungbean' 'maize' 'pigeonpeas' 'pomegranate' 'cotton'
#  'pigeonpeas' 'watermelon' 'mango' 'mungbean' 'pomegranate' 'lentil'
#  'kidneybeans' 'banana' 'mango' 'coffee' 'jute' 'muskmelon' 'cotton'
#  'mothbeans' 'lentil' 'papaya' 'kidneybeans' 'banana' 'cotton'
#  'pigeonpeas' 'pomegranate' 'lentil' 'blackgram' 'cotton' 'coconut'
#  'mungbean' 'watermelon' 'muskmelon' 'rice' 'kidneybeans' 'coconut'
#  'pigeonpeas' 'cotton' 'coffee' 'watermelon' 'mungbean' 'coconut'
#  'mungbean' 'mungbean' 'kidneybeans' 'blackgram' 'jute' 'pomegranate'
#  'banana' 'mungbean' 'blackgram' 'orange' 'mango' 'cotton' 'watermelon'
#  'orange' 'mungbean' 'blackgram' 'orange' 'cotton' 'muskmelon' 'maize'
#  'mango' 'watermelon' 'orange' 'orange' 'chickpea' 'orange' 'papaya'
#  'mango' 'muskmelon' 'muskmelon' 'watermelon' 'watermelon' 'papaya'
#  'mungbean' 'coconut' 'muskmelon' 'mango' 'pigeonpeas' 'coconut'
#  'pomegranate' 'chickpea' 'coffee' 'mothbeans' 'lentil' 'kidneybeans'
#  'pigeonpeas' 'mango' 'blackgram' 'cotton' 'orange' 'mungbean' 'mothbeans'
#  'cotton' 'mothbeans' 'pomegranate' 'kidneybeans' 'kidneybeans'
#  'blackgram' 'pigeonpeas' 'orange' 'mungbean' 'pigeonpeas' 'banana'
#  'mungbean' 'coconut' 'muskmelon' 'coffee' 'blackgram' 'mango' 'orange'
#  'mungbean']

# %%
# Performance Measure
conf_matrix = confusion_matrix(y_test, y_pred)
print(f"Training Accuracy Score: {model.score(X_train_selected, y_train) * 100:.1f}%")
print(f"Validation Accuracy Score: {model.score(X_test_selected, y_test) * 100:.1f}%")
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(pd.DataFrame(conf_matrix), annot=True, cmap='YlGnBu', fmt='g')
ax.xaxis.set_label_position('top')
plt.tight_layout()
plt.title('Confusion Matrix', fontsize=20, y=1.1)
plt.ylabel('Actual label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
print(classification_report(y_test, y_pred))
# Out:
# Training Accuracy Score: 100.0%
# Validation Accuracy Score: 85.3%
#               precision    recall  f1-score   support
#
#       banana       1.00      1.00      1.00        16
#    blackgram       0.78      0.61      0.68        23
#     chickpea       1.00      1.00      1.00        11
#      coconut       0.88      0.88      0.88        16
#       coffee       0.94      1.00      0.97        17
#       cotton       1.00      1.00      1.00        20
#         jute       0.85      0.94      0.89        18
#  kidneybeans       0.73      0.70      0.71        23
#       lentil       0.47      0.43      0.45        21
#        maize       1.00      1.00      1.00        20
#        mango       0.90      0.90      0.90        20
#    mothbeans       0.71      0.50      0.59        10
#     mungbean       0.78      0.93      0.85        27
#    muskmelon       1.00      1.00      1.00        19
#       orange       1.00      1.00      1.00        19
#       papaya       1.00      1.00      1.00        11
#   pigeonpeas       0.32      0.44      0.37        16
#  pomegranate       1.00      1.00      1.00        15
#         rice       1.00      0.67      0.80         9
#   watermelon       1.00      1.00      1.00        23
#
#     accuracy                           0.85       354
#    macro avg       0.87      0.85      0.85       354
# weighted avg       0.86      0.85      0.85       354

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, test_scores = learning_curve(pipeline, X_train, y_train, cv=5, scoring='accuracy', n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10))

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.figure(figsize=(10, 6))
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, color="g", label="Cross-validation score")

plt.title('Learning Curve')
plt.xlabel('Training examples')
plt.ylabel('Score')
plt.legend(loc="best")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb65d1064626> in <cell line: 3>()
#       1 from sklearn.model_selection import learning_curve
#       2
# ----> 3 train_sizes, train_scores, test_scores = learning_curve(pipeline, X_train, y_train, cv=5, scoring='accuracy', n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10))
#       4
#       5 train_scores_mean = np.mean(train_scores, axis=1)
#
# NameError: name 'pipeline' is not defined
